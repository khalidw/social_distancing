# %% [markdown]
# <a href="https://colab.research.google.com/github/khalidw/social_distancing/blob/master/SDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone the code from github

# %%
# !git clone https://github.com/khalidw/social_distancing
# Out:
# Cloning into 'social_distancing'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 20 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %% [markdown]
# # Code requires opencv 4

# %%
# Restart runtime after installing opencv

# %%
# !pip install opencv-python==4.4.0.42
# Out:
# ...
#      |████████████████████████████████| 49.4MB 62kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %% [markdown]
# # Download yolov3 weights

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O /content/social_distancing/yolo-coco/yolov3.weights
# Out:
# --2020-09-16 17:16:39--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘/content/social_distancing/yolo-coco/yolov3.weights’
#
# /content/social_dis 100%[===================>] 236.52M   302KB/s    in 15m 0s
#
# 2020-09-16 17:31:40 (269 KB/s) - ‘/content/social_distancing/yolo-coco/yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # Change current directory

# %%
# %cd /content/social_distancing/
# Out:
# /content/social_distancing

# %% [markdown]
# # Code to run the detector and save output
# ## This is taking time even over GPU runtime. (around 10-20 min)

# %%
# %run social_distance_detector.py --input pedestrians.mp4 --output /content/output.avi --display 0
# Out:
# [INFO] loading YOLO from disk...
# [INFO] setting preferable backend and target to CUDA...
# [INFO] accessing video stream...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/social_distancing/social_distance_detector.py in <module>()
#      64         frame = imutils.resize(frame, width=700)
#      65 	results = detect_people(frame, net, ln,
# ---> 66 		personIdx=LABELS.index("person"))
#      67
#      68         # initialize the set of indexes that violate the minimum social
#
# /content/social_distancing/pyimagesearch/detection.py in detect_people(frame, net, ln, personIdx)
#      15         # and associated probabilities
#      16 	blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416),
# ---> 17 		swapRB=True, crop=False)
#      18         net.setInput(blob)
#      19         layerOutputs = net.forward(ln)
#
# KeyboardInterrupt:

# %% [markdown]
# # Convert output.avi file to mp4 format as avi files are not currently supported

# %%
# !ffmpeg -i /content/output.avi /content/output.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# # Code for displaying output video in cell

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
